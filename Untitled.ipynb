# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("coaster_db.csv")

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      250
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                 991
# Fast Lane available              1018
# Replaced                          914
# ...

# %%
df.isnull().mean()*100
# Out:
# coaster_name                      0.000000
# Length                           12.327507
# Speed                            13.799448
# Location                          0.000000
# Status                           19.595216
# Opening date                     22.999080
# Type                              0.000000
# Manufacturer                      5.427783
# Height restriction               23.551058
# Model                            31.554738
# Height                           11.223551
# Inversions                       14.259430
# Lift/launch system               26.862925
# Cost                             64.857406
# Trains                           33.946642
# Park section                     55.197792
# Duration                         29.622815
# Capacity                         47.102116
# G-force                          66.697332
# Designer                         46.826127
# Max vertical angle               67.157314
# Drop                             54.553818
# ...

# %%
len(df["coaster_name"].unique())
# Out:
# 990

# %%
for i in df.columns:
    print("-"*50)
    print(i,"\n")
    print("unique values are:",len(df[i].unique()))
# Out:
# --------------------------------------------------
# coaster_name
#
# unique values are: 990
# --------------------------------------------------
# Length
#
# unique values are: 570
# --------------------------------------------------
# Speed
#
# unique values are: 244
# --------------------------------------------------
# Location
#
# unique values are: 280
# --------------------------------------------------
# Status
#
# unique values are: 16
# --------------------------------------------------
# Opening date
#
# unique values are: 657
# --------------------------------------------------
# Type
#
# unique values are: 98
# --------------------------------------------------
# Manufacturer
#
# unique values are: 103
# --------------------------------------------------
# Height restriction
#
# unique values are: 101
# --------------------------------------------------
# Model
#
# unique values are: 318
# --------------------------------------------------
# Height
#
# ...

# %%
df["Status"].value_counts()
# Out:
# Operating                                                         668
# Removed                                                           137
# Closed                                                             24
# Under construction                                                 15
# In Production                                                      11
# Discontinued                                                        7
# Closed in 2021                                                      2
# SBNO December 2019                                                  2
# Chapter 7 bankruptcy; rides dismantled and sold; property sold      2
# Not Currently Operating                                             1
# closed for maintenance as of july 30 no reopening date known        1
# Temporarily Closed                                                  1
# SBNO (Standing But Not Operating)                                   1
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df
# Out:
#                                 coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
#  droppng irrelevant columns

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df=df[['coaster_name', 
#     'Length', 'Speed', 
    'Location', 'Status', 
    'Opening date',
#        'Type', 
    'Manufacturer', 
#     'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean',
#     'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
#     'height_value', 'height_unit', 
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df
# Out:
#                                 coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df.shape
# Out:
# (1087, 14)

# %%
df.isnull().sum()
# Out:
# coaster_name            0
# Location                0
# Status                213
# Opening date          250
# Manufacturer           59
# year_introduced         0
# latitude              275
# longitude             275
# Type_Main               0
# opening_date_clean    250
# speed_mph             150
# height_ft             916
# Inversions_clean        0
# Gforce_clean          725
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Location            1087 non-null   object
#  2   Status              874 non-null    object
#  3   Opening date        837 non-null    object
#  4   Manufacturer        1028 non-null   object
#  5   year_introduced     1087 non-null   int64
#  6   latitude            812 non-null    float64
#  7   longitude           812 non-null    float64
#  8   Type_Main           1087 non-null   object
#  9   opening_date_clean  837 non-null    object
#  10  speed_mph           937 non-null    float64
#  11  height_ft           171 non-null    float64
#  12  Inversions_clean    1087 non-null   int64
#  13  Gforce_clean        362 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 119.0+ KB

# %%
df["opening_date_clean"]=pd.to_datetime(df["opening_date_clean"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Location            1087 non-null   object
#  2   Status              874 non-null    object
#  3   Opening date        837 non-null    object
#  4   Manufacturer        1028 non-null   object
#  5   year_introduced     1087 non-null   int64
#  6   latitude            812 non-null    float64
#  7   longitude           812 non-null    float64
#  8   Type_Main           1087 non-null   object
#  9   opening_date_clean  837 non-null    datetime64[ns]
#  10  speed_mph           937 non-null    float64
#  11  height_ft           171 non-null    float64
#  12  Inversions_clean    1087 non-null   int64
#  13  Gforce_clean        362 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(6)
# ...

# %%
#  rename the colums
for i in df.columns:
    df=df.rename(columns={i:i.upper()})
    print(i.upper())
# Out:
# COASTER_NAME
# LOCATION
# STATUS
# OPENING DATE
# MANUFACTURER
# YEAR_INTRODUCED
# LATITUDE
# LONGITUDE
# TYPE_MAIN
# OPENING_DATE_CLEAN
# SPEED_MPH
# HEIGHT_FT
# INVERSIONS_CLEAN
# GFORCE_CLEAN

# %%
df.head()
# Out:
#                              COASTER_NAME                        LOCATION  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     STATUS   OPENING DATE            MANUFACTURER  YEAR_INTRODUCED  LATITUDE  \
# 0  Removed  June 16, 1884  LaMarcus Adna Thompson             1884   40.5740
# 1  Removed           1895            Lina Beecher             1895   40.5780
# 2   Closed            NaN                     NaN             1896   41.5800
# 3  Removed           1901          Edwin Prescott             1901   40.5745
# 4  Removed           1901          Edwin Prescott             1901   39.3538
#
# ...

# %%
df.isnull().sum()
# Out:
# COASTER_NAME            0
# LOCATION                0
# STATUS                213
# OPENING DATE          250
# MANUFACTURER           59
# YEAR_INTRODUCED         0
# LATITUDE              275
# LONGITUDE             275
# TYPE_MAIN               0
# OPENING_DATE_CLEAN    250
# SPEED_MPH             150
# HEIGHT_FT             916
# INVERSIONS_CLEAN        0
# GFORCE_CLEAN          725
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [COASTER_NAME, LOCATION, STATUS, OPENING DATE, MANUFACTURER, YEAR_INTRODUCED, LATITUDE, LONGITUDE, TYPE_MAIN, OPENING_DATE_CLEAN, SPEED_MPH, HEIGHT_FT, INVERSIONS_CLEAN, GFORCE_CLEAN]
# Index: []

# %%
#  duplicate on the subset
df[df.duplicated(subset="COASTER_NAME")].head()
# Out:
#                           COASTER_NAME             LOCATION     STATUS  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           OPENING DATE  \
# 43                                                1926
# 60                                                1911
# 61                                        May 23, 1938
# 167                                                NaN
# 237  May 23, 1981 as Blauer Enzian, 1986 as Thunder...
#
#                                           MANUFACTURER  YEAR_INTRODUCED  \
# 43                                  Traver Engineering             1927
# ...

# %%
df.query("COASTER_NAME=='Crystal Beach Cyclone'")
# Out:
#              COASTER_NAME            LOCATION   STATUS OPENING DATE  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed         1926
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed         1926
#
#           MANUFACTURER  YEAR_INTRODUCED  LATITUDE  LONGITUDE TYPE_MAIN  \
# 39  Traver Engineering             1926   42.8617   -79.0598      Wood
# 43  Traver Engineering             1927   42.8617   -79.0598      Wood
#
#    OPENING_DATE_CLEAN  SPEED_MPH  HEIGHT_FT  INVERSIONS_CLEAN  GFORCE_CLEAN
# 39         1926-01-01       60.0        NaN                 0           4.0
# 43         1926-01-01       60.0        NaN                 0           4.0

# %%
#  duplicate on the subset
df=df[~df.duplicated(subset=["COASTER_NAME","LOCATION","OPENING_DATE_CLEAN"])].reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (990, 13)

# %%
df=df.drop(columns="OPENING DATE")

# %%
#  feature understanding

# %%
# # univariant analysis
# 1. histogram
# 2. KDE
# 3. Boxplot

# %%
df["YEAR_INTRODUCED"].value_counts()
# Out:
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: YEAR_INTRODUCED, Length: 101, dtype: int64

# %%
ax=df["YEAR_INTRODUCED"].value_counts().head(10).plot(kind="bar",title="top years worker interduce", color="g")

ax.set_xlabel("Year")
ax.set_ylabel("number of workers")
# Out:
# Text(0, 0.5, 'number of workers')

# %%
ax=df["SPEED_MPH"].plot(kind="hist",bins=20,title="cluster speed miles per hour")
ax.set_xlabel("speed mph")
# Out:
# Text(0.5, 0, 'speed mph')

# %%
ax=df["SPEED_MPH"].plot(kind="kde",title="cluster speed miles per hour")
ax.set_xlabel("speed mph")
# Out:
# Text(0.5, 0, 'speed mph')

# %%
# #  featuree realtionship
# 1. scatter plot
# 2. heatmap correleation
# 3. pairplot
# 4. group by compaisons

# %%
sns.scatterplot(x="SPEED_MPH",y="HEIGHT_FT", data=df,hue="YEAR_INTRODUCED")
plt.title("speed vs height")
# Out:
# Text(0.5, 1.0, 'speed vs height')

# %%
sns.pairplot(df,vars=['YEAR_INTRODUCED','SPEED_MPH',
                   'HEIGHT_FT','INVERSIONS_CLEAN','GFORCE_CLEAN'],
             kind="scatter",
             hue="TYPE_MAIN")

# %%
df[['YEAR_INTRODUCED','SPEED_MPH','HEIGHT_FT','INVERSIONS_CLEAN','GFORCE_CLEAN']].dropna().corr()
# Out:
#                   YEAR_INTRODUCED  SPEED_MPH  HEIGHT_FT  INVERSIONS_CLEAN  \
# YEAR_INTRODUCED          1.000000   0.171978   0.135413         -0.209887
# SPEED_MPH                0.171978   1.000000   0.733999         -0.028705
# HEIGHT_FT                0.135413   0.733999   1.000000         -0.079736
# INVERSIONS_CLEAN        -0.209887  -0.028705  -0.079736          1.000000
# GFORCE_CLEAN             0.160247   0.607383   0.466482          0.275991
#
#                   GFORCE_CLEAN
# YEAR_INTRODUCED       0.160247
# SPEED_MPH             0.607383
# HEIGHT_FT             0.466482
# INVERSIONS_CLEAN      0.275991
# GFORCE_CLEAN          1.000000

# %%
sns.heatmap(df[['YEAR_INTRODUCED','SPEED_MPH','HEIGHT_FT','INVERSIONS_CLEAN','GFORCE_CLEAN']].dropna().corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
#  what are the location with the fatstest roler coster(minimum 0of 10)

df["LOCATION"].value_counts()
# Out:
# Other                            181
# Kings Island                      19
# Cedar Point                       18
# Six Flags Magic Mountain          17
# Hersheypark                       16
#                                 ...
# Granada Studios Tour               1
# Funtown Splashtown USA             1
# Tolchester Beach Park              1
# Suzuka, Mie Prefecture, Japan      1
# Epcot                              1
# Name: LOCATION, Length: 280, dtype: int64

# %%
df.query("LOCATION!='Other'").groupby("LOCATION")["SPEED_MPH"].agg(["mean","count"])\
.query("count>=10").sort_values("count").plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='LOCATION'>
